# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

stock_price = pd.read_csv('/content/sample_data/AAPL.csv')
stock_price.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 1  2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2  2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 3  2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 4  2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100

# %%
stock_price.shape
# Out:
# (2011, 7)

# %%
stock_price.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
stock_price.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
stock_price_preprocessed = stock_price.drop_duplicates(subset=['Date'], keep='first')

stock_price_preprocessed.shape#There are noo duplicates or null values in the dataset
# Out:
# (2011, 7)

# %%
stock_price_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   object
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.1+ KB

# %%
#Type casting date column from Object to datetime
stock_price_preprocessed['Date'] = pd.to_datetime(stock_price_preprocessed['Date'], format="%Y-%m-%d") #changing the datatype of the date column
##from object to datetime
stock_price_preprocessed.info() #cross checking the datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   datetime64[ns]
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 110.1 KB

# %%
stock_price_preprocessed.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2011  2011.000000  2011.000000  2011.000000
# mean   2016-01-01 03:10:28.344107520   126.707469   127.827594   125.580258
# min              2012-01-03 00:00:00    55.424286    57.085712    55.014286
# 25%              2014-01-02 12:00:00    85.882858    86.717858    85.056427
# 50%              2015-12-31 00:00:00   113.050003   114.190002   111.870003
# 75%              2017-12-28 12:00:00   165.190002   167.409996   163.424995
# max              2019-12-30 00:00:00   291.119995   293.970001   288.119995
# std                              NaN    50.483753    50.926301    50.124940
#
#              Close    Adj Close        Volume
# count  2011.000000  2011.000000  2.011000e+03
# mean    126.741235   119.505548  5.949670e+07
# min      55.790001    48.921928  1.136200e+07
# 25%      86.202145    75.056679  2.758565e+07
# 50%     113.050003   105.222908  4.346900e+07
# 75%     165.245002   160.047111  7.471030e+07
# max     291.519989   289.522614  3.765300e+08
# std      50.578369    52.438444  4.683856e+07

# %%
corelation = stock_price_preprocessed.corr(numeric_only=True)
corelation
##There is high corelation between open and Adj close
##negative relation between volume and other colunms
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999782  0.999718  0.999496   0.998895 -0.557956
# High       0.999782  1.000000  0.999657  0.999748   0.999171 -0.554909
# Low        0.999718  0.999657  1.000000  0.999769   0.999179 -0.563426
# Close      0.999496  0.999748  0.999769  1.000000   0.999402 -0.559654
# Adj Close  0.998895  0.999171  0.999179  0.999402   1.000000 -0.566332
# Volume    -0.557956 -0.554909 -0.563426 -0.559654  -0.566332  1.000000

# %% [markdown]
# # Identifying Outliers

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=stock_price_preprocessed[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']], palette='Set2')
plt.title('Boxplot for Outlier Detection')
plt.grid()
plt.show()
#The volume column has a lot of outliers. So the column is being dropped for model building

# %%
stock_price_preprocessed = stock_price_preprocessed.drop('Volume',axis=1)
#the Volume column contains a high number of extreme outliers, which could negatively impact model performance and also its not required in our prediction

# %%
sns.heatmap(corelation,annot=True)
plt.show()

# %% [markdown]
# # **visualazation**

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.pairplot(stock_price_preprocessed[['Open', 'High', 'Low', 'Close']])
plt.show()
#The Open, High, Low, and Close prices likely show strong positive correlations with each other.

# %%
# Plot the stock prices (Open, High, Low, Close) over time
stock_price_preprocessed[['Open', 'High', 'Low', 'Close']].plot(figsize=(12,6), title="Stock Price Over Time")
plt.grid(True)
plt.show()

# %%
# Moving Averages for Open, High, Low, Close
for col in ['Open', 'High', 'Low', 'Close']:
    stock_price_preprocessed[f'{col}_30MA'] = stock_price_preprocessed[col].rolling(window=30).mean()
    stock_price_preprocessed[f'{col}_60MA'] = stock_price_preprocessed[col].rolling(window=60).mean()

plt.figure(figsize=(12,6))
for col in ['Open', 'High', 'Low', 'Close']:
    plt.plot(stock_price_preprocessed[col], label=f'{col} Price')
    plt.plot(stock_price_preprocessed[f'{col}_30MA'], label=f'30-Day MA {col}', linestyle='dashed')
    plt.plot(stock_price_preprocessed[f'{col}_60MA'], label=f'60-Day MA {col}', linestyle='dotted')
plt.legend()
plt.grid(True)
plt.title("Stock Price with Moving Averages")
plt.show()
##The 30-day one is more sensitive to recent changes, while the 60-day average gives a smoother long-term trend.

# %%
stock_price_preprocessed.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709
# 1 2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536
# 2 2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175
# 3 2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630
# 4 2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932
#
#    Open_30MA  Open_60MA  High_30MA  High_60MA  Low_30MA  Low_60MA  Close_30MA  \
# 0        NaN        NaN        NaN        NaN       NaN       NaN         NaN
# 1        NaN        NaN        NaN        NaN       NaN       NaN         NaN
# 2        NaN        NaN        NaN        NaN       NaN       NaN         NaN
# 3        NaN        NaN        NaN        NaN       NaN       NaN         NaN
# 4        NaN        NaN        NaN        NaN       NaN       NaN         NaN
#
#    Close_60MA
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# **MODELS**

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report, r2_score
import matplotlib.pyplot as plt

# Defining features (independent variables) and target variable (dependent variable)
x = stock_price_preprocessed[['Open', 'High', 'Low', 'Close']]  # Feature set
y = stock_price_preprocessed['Adj Close']  # Target variable

# Splitting the dataset into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initializing the XGBoost regressor model with specific hyperparameters
model = xgb.XGBRegressor(
    objective='reg:squarederror',  # Defining the regression objective
    n_estimators=100,  # Number of boosting rounds
    learning_rate=0.1,  # Step size shrinkage to prevent overfitting
    max_depth=5  # Maximum depth of a tree to control complexity
)

# Training the XGBoost model on the training dataset
model.fit(x_train, y_train)

# Making predictions on the test dataset
y_pred = model.predict(x_test)

# Calculating performance metrics to evaluate model accuracy
mae = mean_absolute_error(y_test, y_pred)  # Mean Absolute Error
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error
print(f"MAE: {mae}, MSE: {mse}, RMSE: {rmse}")
print(r2_score(y_test, y_pred))  # R-squared score to measure goodness of fit

# Plotting the actual vs predicted stock prices
plt.figure(figsize=(10, 5))  # Setting figure size
plt.plot(range(len(y_test)), y_test, label="Actual Prices", color='blue')  # Actual prices plot
plt.plot(range(len(y_test)), y_pred, label="Predicted Prices", color='red', linestyle="dashed")  # Predicted prices plot

# Adding labels and title to the plot
plt.xlabel("Index (Time Steps)")  # X-axis label
plt.ylabel("Stock Price")  # Y-axis label
plt.title("Apple Stock Price Prediction: Actual vs Predicted")  # Plot title
plt.legend()  # Display legend for labels
plt.show()  # Display the plot
# Out:
# MAE: 1.1294993914852474, MSE: 2.5666652937460253, RMSE: 1.6020815502795185
# 0.9990501446150368
